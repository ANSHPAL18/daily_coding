# %%
print("hello")
# Out:
# hello

# %%
print("$₹.☠️")
# Out:
# $₹.☠️

# %%
print(11//2)
# Out:
# 5

# %%
print("what is your age")
a=input()
print(a)
# Out:
# what is your age
# 18

# %%
a=input()
print("a")
print(a)
# Out:
# a
# 3

# %%
print("1"+"2"+"3")
print("1","2"," 3")
# Out:
# 123
# 1 2  3

# %%
firstname=input()
lastname=input()
print(lastname,"hello world",firstname)
# Out:
# pal hello world ansh

# %%
a=5

print(type(a))
# Out:
# <class 'int'>

# %%
a=input(" what is x?")
b=input(" what is y?")
print(a,b)
# Out:
# abc def

# %%
chr(67)
# Out:
# 'C'

# %%
a=int(input())
if a>5:
    print("hello")
elif a<5:
    print("world")
else:
    print(" hi")
# Out:
# hello

# %%
a=1
if a==1:
    print("1")
print("2")
print("hi"*5)
# Out:
# 1
# 2
# hihihihihi

# %%
print("hi","hi",sep="\t")
# Out:
# hi	hi

# %%
guess=input("what is the capital of INDIA?")
if guess=="DELHI":
    print("you won")
else:
    print("you lose")
# Out:
# you lose

# %%
print((5)*3)
# Out:
# 15
